# %%
import pandas as pd

# %%
from tqdm.auto import tqdm

# %%
from sqlalchemy import create_engine

# %%
import pyarrow.parquet as pq

# %%
url='https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2025-11.parquet'

# %%
url
# Out:
# 'https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2025-11.parquet'

# %%
df = pd.read_parquet(url)

# %%
len(df)
# Out:
# 46912

# %%
batch_size = 10000

# %%
print(df.dtypes)
# Out:
# VendorID                          int32
# lpep_pickup_datetime     datetime64[us]
# lpep_dropoff_datetime    datetime64[us]
# store_and_fwd_flag               object
# RatecodeID                      float64
# PULocationID                      int32
# DOLocationID                      int32
# passenger_count                 float64
# trip_distance                   float64
# fare_amount                     float64
# extra                           float64
# mta_tax                         float64
# tip_amount                      float64
# tolls_amount                    float64
# ehail_fee                       float64
# improvement_surcharge           float64
# total_amount                    float64
# payment_type                    float64
# trip_type                       float64
# congestion_surcharge            float64
# cbd_congestion_fee              float64
# dtype: object

# %%
parquet_file = pq.ParquetFile(url)
# Out:
# ---------------------------------------------------------------------------
# ArrowInvalid                              Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 parquet_file = pq.ParquetFile(url)
#
# File ~/workspace/VisualStudio/GitHubProjects/de-tools-docker-terraform/docker-postgresql/.venv/lib/python3.14/site-packages/pyarrow/parquet/core.py:321, in ParquetFile.__init__(self, source, metadata, common_metadata, read_dictionary, binary_type, list_type, memory_map, buffer_size, pre_buffer, coerce_int96_timestamp_unit, decryption_properties, thrift_string_size_limit, thrift_container_size_limit, filesystem, page_checksum_verification, arrow_extensions_enabled)
#     311 def __init__(self, source, *, metadata=None, common_metadata=None,
#     312              read_dictionary=None, binary_type=None, list_type=None,
#     313              memory_map=False, buffer_size=0, pre_buffer=False,
# ...

# %%
engine = create_engine(f'postgresql://root:root@localhost:5433/ny_taxi')

# %%
engine
# Out:
# Engine(postgresql://root:***@localhost:5433/ny_taxi)

# %%
df = pd.read_parquet(url)

# %%
df.head(n=0).to_sql(name='table01', con=engine, if_exists='replace')
# Out:
# 0

# %%
df.to_sql(name='table01', con=engine, if_exists='append')
# Out:
# 912

# %%
url_csv='https://github.com/DataTalksClub/nyc-tlc-data/releases/download/misc/taxi_zone_lookup.csv'

# %%
df = pd.read_csv(url_csv)

# %%
df.head()
# Out:
#    LocationID        Borough                     Zone service_zone
# 0           1            EWR           Newark Airport          EWR
# 1           2         Queens              Jamaica Bay    Boro Zone
# 2           3          Bronx  Allerton/Pelham Gardens    Boro Zone
# 3           4      Manhattan            Alphabet City  Yellow Zone
# 4           5  Staten Island            Arden Heights    Boro Zone

# %%
len(df)
# Out:
# 265

# %%
df.dtypes
# Out:
# LocationID       int64
# Borough         object
# Zone            object
# service_zone    object
# dtype: object

# %%
var_dtype = {
    "LocationID": "Int64",
    "Borough": "string",
    "Zone": "string",
    "service_zone": "string"
}

df = pd.read_csv(url_csv, dtype=var_dtype)

# %%
len(df)
# Out:
# 265

# %%
df.head(n=0).to_sql(name='table02', con=engine, if_exists='replace')
# Out:
# 0

# %%
df.to_sql(name='table02', con=engine, if_exists='append')
# Out:
# 265
